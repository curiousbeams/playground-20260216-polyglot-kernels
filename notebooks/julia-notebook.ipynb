# %%
# Julia cell - interactive plot example
using Plots
plotlyjs()

# Create sample data
x = range(0, 2π, length=100)
y1 = sin.(x)
y2 = cos.(x);
# Out:
# WebIO._IJuliaInit()

# %%
#| label:julia-output
plot(x, [y1 y2], 
     label=["sin(x)" "cos(x)"],
     xlabel="x", 
     ylabel="y",
     title="Interactive Trigonometric Functions",
     linewidth=2,
     legend=:topright
)
